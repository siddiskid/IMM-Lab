# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "VML_FINAL_DATA.csv"
df = pd.read_csv(file_path, sep=",")
print(df.head())
# Out:
#          subID  sub  run  trial  direction  ResponseTime  MovementTime  \
# 0  VML_MEG_002    1    1      1         -1         0.349         1.024
# 1  VML_MEG_002    1    1      2          1         0.299         1.167
# 2  VML_MEG_002    1    1      3         -1         0.384         1.069
# 3  VML_MEG_002    1    1      4          1         0.223         1.056
# 4  VML_MEG_002    1    1      5          1         0.318         1.148
#
#    ErrorAngle  AccelerationAngle  Accuracy  TimePeakVelocity  \
# 0      6.1214            3.33880         1             0.472
# 1     -9.1269          -14.44800         1             0.458
# 2     -3.3358           -0.89402         1             0.652
# 3    -12.8280          -14.04800         1             0.401
# 4      9.7389            2.66900         1             0.434
#
#    DistancePeakVelocity  PeakVelocity  PeakAcceleration  \
# 0                4.2234        53.232           1055.90
# ...

# %%
import matplotlib.pyplot as plt

all_subjects_grouped = df.groupby(['sub'])

for subject_id, subject_df in all_subjects_grouped:
    plt.figure(figsize=(9, 6))
    
    subject_runs_grouped = subject_df.groupby(['run'])
    
    for run_id, run_df in subject_runs_grouped:
        plt.plot(run_df['trial'], run_df['ErrorAngle'].abs(), marker='o', linestyle='-', label=f'Run {run_id[0]}')
        
    plt.title(f'Absolute Error Angle vs. Trial for Subject {subject_id[0]}')
    
    plt.xlabel('Trial')
    plt.ylabel('Absolute Error Angle')
    plt.grid(True)
    plt.legend()
    plt.show()
